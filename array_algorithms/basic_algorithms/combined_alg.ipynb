# %% [markdown]
# # Combined Processing Algorithm
#
# Example simulating the ability of the array to both simultaneously locate and isolate sources

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pyroomacoustics as pra
from pyroomacoustics.directivities import (
    DirectivityPattern,
    DirectionVector,
    CardioidFamily,
)
from scipy.io import wavfile
from scipy.signal import resample
from playsound import playsound

# %% [markdown]
# ### Room parameters

# %%
fs = 8000 # audio sampling frequency - global (set to freq of input file)

room_x = 10 # stage width
room_y = 20 # room length
order = 0 # reflection order
sigma2_n = 5e-7 # microphone noise variance estimate
v_sound = 343.0 # speed of sound in air

m = pra.make_materials(
    ceiling="hard_surface",
    floor="stage_floor",
    east="brickwork",
    west="brickwork",
    north="brickwork",
    south="brickwork",
) # materials of each surface of room, defines signal absorption

room = pra.ShoeBox([room_x, room_y], fs=fs, materials=m, max_order=order, air_absorption=True, ray_tracing=False)

# %% [markdown]
# ### Place mics

# %%
# design parameters of array
array_loc = [5, 15] # x/y location of array center
n_mics = 8 # number of microphones
sep = 0.3 # microphone separation

N = 1024 # fft length - defines N/2 + 1 frequency bands

R = pra.linear_2D_array(center=array_loc, M=n_mics, phi=0, d=sep)
mic_array = pra.Beamformer(R, room.fs, N) # uses omnidirectional mics by default
room.add_microphone_array(mic_array)

# %% [markdown]
# ### Place sources

# %%
source_locs = [[3, 19], [5, 19], [7, 19]] # locations of each source in 3D space (can modify)
source_inputs = ['input_samples/singing_8000.wav', 'input_samples/german_speech_8000.wav', 'input_samples/cmu_arctic_us_aew_a0001.wav'] # filepaths to wav files being played by the source
azimuths = []

for i in range(len(source_locs)):
    rate, audio = wavfile.read(source_inputs[i])

    # ensure sampling rates of all audio matches
    if rate != fs:
        num_samples = int(len(audio) * fs / rate)
        audio = resample(audio, num_samples)
    
    room.add_source(source_locs[i], signal=audio, delay=0)

    # ground truth azimuths (calculated relative to the x axis)
    azimuths.append(180/np.pi * math.atan2(source_locs[i][1] - array_loc[1], source_locs[i][0] - array_loc[0]))
    
azimuths.sort()
print('Source azimuths:', azimuths)
# Out:
# Source azimuths: [63.43494882292201, 90.0, 116.56505117707799]

# %% [markdown]
# ### Locate sources with DOA

# %%
room.compute_rir()
room.simulate()

# short-time fourier transform of signal
X = np.array(
    [
        pra.transform.stft.analysis(signal, N, N // 2).T
        for signal in room.mic_array.signals
    ]
)

# NormMUSIC algorithm selected, recommended over MUSIC
n_source = 3
doa = pra.doa.normmusic.NormMUSIC(R, fs, N, c=v_sound, num_src=n_source, mode='far', azimuth=np.linspace(0, 180, 30)*np.pi/180)
doa.locate_sources(X, freq_bins=np.arange(1, N))
doa_azimuths = doa.azimuth_recon
doa_azimuths.sort()
azimuth_errors = [azimuths[i] - doa_azimuths[i] * 180.0/np.pi for i in range(len(azimuths))]

print("Recovered azimuths:", doa_azimuths * 180.0/np.pi, "degrees")
print("Angular Errors:", azimuth_errors, "degrees")
# Out:
# Recovered azimuths: [ 62.06896552  86.89655172 117.93103448] degrees
# Angular Errors: [1.3659833056806292, 3.103448275862064, -1.3659833056806292] degrees

# %% [markdown]
# ### Isolate sources with beamforming

# %%
# add guessed locations of sources to room
guess_dist = 5 # guessed distance away from array - choose far distance for precise beam
guess_source_locs = np.empty((2, n_source))

for i in range(n_source):
    guess_source_locs[0, i] = array_loc[0] + guess_dist*np.cos(doa_azimuths[i])
    guess_source_locs[1, i] = array_loc[1] + guess_dist*np.sin(doa_azimuths[i])

# Beamforming algorithm for each source
out_filepath = 'output_samples/DOA_Combined'
# guessed_sources = [room.sources[i][0:1] for i in range(n_source, 2*n_source)]

for i in range(guess_source_locs.shape[1]):
    current_interferers = guess_source_locs
    current_interferers = np.delete(current_interferers, i, 1)

    interf = pra.soundsource.SoundSource([0, 0])
    interf.images = current_interferers

    source = pra.soundsource.SoundSource([0, 0])
    source.images = np.array([[guess_source_locs[0, i]], [guess_source_locs[1, i]]])

    mic_array.rake_one_forcing_weights(
        source=source,
        interferer=interf,
        R_n=sigma2_n * np.eye(mic_array.M) # estimated noise covariance matrix
    )
    mic_array.filters_from_weights() # process with time domain filters for now, can also use FD directly

    # compute SIR, averaged across all frequency bands
    SIR_sum = 0
    for f in mic_array.frequencies:
        current_SIR = mic_array.snr(source, interf, f, dB=True)
        if math.isnan(current_SIR) == False:
            SIR_sum += current_SIR
            print(f'frequency band: {f:.2f}, SINR: {current_SIR:.2f}')
    SIR_avg = SIR_sum / len(mic_array.frequencies)
    print(f'average SINR: {SIR_avg:.2f}')

    # save processed sound as output
    output = mic_array.process()
    out_norm = pra.normalize(output)
    wavfile.write(out_filepath + '/isolated_src' + str(i+1) + '.wav', fs, out_norm)

# save sound from middle mic as an estimated raw input
raw_mic = pra.normalize(mic_array.signals[mic_array.M // 2])
wavfile.write(out_filepath + '/combined_8000_mic_' + str(mic_array.M // 2) + '.wav', fs, raw_mic)
# Out:
# frequency band: 0.00, SINR: 36.43
# frequency band: 7.81, SINR: 40.06
# frequency band: 15.62, SINR: 46.18
# frequency band: 23.44, SINR: 51.49
# frequency band: 31.25, SINR: 55.78
# frequency band: 39.06, SINR: 59.31
# frequency band: 46.88, SINR: 62.28
# frequency band: 54.69, SINR: 64.84
# frequency band: 62.50, SINR: 67.08
# frequency band: 70.31, SINR: 69.08
# frequency band: 78.12, SINR: 70.88
# frequency band: 85.94, SINR: 72.52
# frequency band: 93.75, SINR: 74.03
# frequency band: 101.56, SINR: 75.44
# frequency band: 109.38, SINR: 76.77
# frequency band: 117.19, SINR: 78.02
# frequency band: 125.00, SINR: 79.22
# frequency band: 132.81, SINR: 80.37
# frequency band: 140.62, SINR: 81.49
# frequency band: 148.44, SINR: 82.58
# frequency band: 156.25, SINR: 83.66
# frequency band: 164.06, SINR: 84.73
# frequency band: 171.88, SINR: 85.79
# frequency band: 179.69, SINR: 86.85
# frequency band: 187.50, SINR: 87.91
# frequency band: 195.31, SINR: 88.97
# frequency band: 203.12, SINR: 90.02
# frequency band: 210.94, SINR: 91.04
# frequency band: 218.75, SINR: 92.03
# frequency band: 226.56, SINR: 92.95
# frequency band: 234.38, SINR: 93.80
# frequency band: 242.19, SINR: 94.52
# frequency band: 250.00, SINR: 95.12
# frequency band: 257.81, SINR: 95.56
# frequency band: 265.62, SINR: 95.83
# frequency band: 273.44, SINR: 95.95
# frequency band: 281.25, SINR: 95.93
# frequency band: 289.06, SINR: 95.79
# frequency band: 296.88, SINR: 95.57
# frequency band: 304.69, SINR: 95.31
# frequency band: 312.50, SINR: 95.06
# frequency band: 320.31, SINR: 94.84
# frequency band: 328.12, SINR: 94.70
# frequency band: 335.94, SINR: 94.66
# frequency band: 343.75, SINR: 94.78
# frequency band: 351.56, SINR: 95.07
# frequency band: 359.38, SINR: 95.59
# frequency band: 367.19, SINR: 96.39
# frequency band: 375.00, SINR: 97.56
# frequency band: 382.81, SINR: 99.22
# frequency band: 390.62, SINR: 101.59
# frequency band: 398.44, SINR: 104.82
# frequency band: 406.25, SINR: 107.25
# frequency band: 414.06, SINR: 104.62
# frequency band: 421.88, SINR: 100.66
# frequency band: 429.69, SINR: 97.52
# frequency band: 437.50, SINR: 95.11
# frequency band: 445.31, SINR: 93.19
# frequency band: 453.12, SINR: 91.64
# frequency band: 460.94, SINR: 90.37
# frequency band: 468.75, SINR: 89.32
# frequency band: 476.56, SINR: 88.46
# frequency band: 484.38, SINR: 87.77
# frequency band: 492.19, SINR: 87.22
# frequency band: 500.00, SINR: 86.80
# frequency band: 507.81, SINR: 86.51
# frequency band: 515.62, SINR: 86.34
# frequency band: 523.44, SINR: 86.29
# frequency band: 531.25, SINR: 86.35
# frequency band: 539.06, SINR: 86.52
# frequency band: 546.88, SINR: 86.80
# frequency band: 554.69, SINR: 87.19
# frequency band: 562.50, SINR: 87.70
# frequency band: 570.31, SINR: 88.31
# frequency band: 578.12, SINR: 89.05
# frequency band: 585.94, SINR: 89.92
# frequency band: 593.75, SINR: 90.94
# frequency band: 601.56, SINR: 92.13
# frequency band: 609.38, SINR: 93.52
# frequency band: 617.19, SINR: 95.16
# frequency band: 625.00, SINR: 97.15
# frequency band: 632.81, SINR: 99.61
# frequency band: 640.62, SINR: 102.76
# frequency band: 648.44, SINR: 106.73
# frequency band: 656.25, SINR: 109.55
# frequency band: 664.06, SINR: 107.23
# frequency band: 671.88, SINR: 103.91
# frequency band: 679.69, SINR: 101.42
# frequency band: 687.50, SINR: 99.63
# frequency band: 695.31, SINR: 98.32
# frequency band: 703.12, SINR: 97.38
# frequency band: 710.94, SINR: 96.71
# frequency band: 718.75, SINR: 96.28
# frequency band: 726.56, SINR: 96.04
# frequency band: 734.38, SINR: 95.99
# frequency band: 742.19, SINR: 96.09
# frequency band: 750.00, SINR: 96.36
# frequency band: 757.81, SINR: 96.77
# frequency band: 765.62, SINR: 97.33
# frequency band: 773.44, SINR: 98.02
# frequency band: 781.25, SINR: 98.83
# frequency band: 789.06, SINR: 99.74
# frequency band: 796.88, SINR: 100.67
# frequency band: 804.69, SINR: 101.55
# frequency band: 812.50, SINR: 102.24
# frequency band: 820.31, SINR: 102.63
# frequency band: 828.12, SINR: 102.70
# frequency band: 835.94, SINR: 102.50
# frequency band: 843.75, SINR: 102.18
# frequency band: 851.56, SINR: 101.84
# frequency band: 859.38, SINR: 101.54
# frequency band: 867.19, SINR: 101.30
# frequency band: 875.00, SINR: 101.08
# frequency band: 882.81, SINR: 100.82
# frequency band: 890.62, SINR: 100.43
# frequency band: 898.44, SINR: 99.81
# frequency band: 906.25, SINR: 98.93
# frequency band: 914.06, SINR: 97.86
# frequency band: 921.88, SINR: 96.68
# frequency band: 929.69, SINR: 95.47
# frequency band: 937.50, SINR: 94.32
# frequency band: 945.31, SINR: 93.25
# frequency band: 953.12, SINR: 92.29
# frequency band: 960.94, SINR: 91.47
# frequency band: 968.75, SINR: 90.79
# frequency band: 976.56, SINR: 90.25
# frequency band: 984.38, SINR: 89.86
# frequency band: 992.19, SINR: 89.63
# frequency band: 1000.00, SINR: 89.57
# frequency band: 1007.81, SINR: 89.71
# frequency band: 1015.62, SINR: 90.05
# frequency band: 1023.44, SINR: 90.64
# frequency band: 1031.25, SINR: 91.52
# frequency band: 1039.06, SINR: 92.79
# frequency band: 1046.88, SINR: 94.60
# frequency band: 1054.69, SINR: 97.32
# frequency band: 1062.50, SINR: 101.94
# frequency band: 1070.31, SINR: 114.73
# frequency band: 1078.12, SINR: 106.01
# frequency band: 1085.94, SINR: 98.21
# frequency band: 1093.75, SINR: 93.93
# frequency band: 1101.56, SINR: 90.89
# frequency band: 1109.38, SINR: 88.50
# frequency band: 1117.19, SINR: 86.50
# frequency band: 1125.00, SINR: 84.75
# frequency band: 1132.81, SINR: 83.17
# frequency band: 1140.62, SINR: 81.72
# frequency band: 1148.44, SINR: 80.37
# frequency band: 1156.25, SINR: 79.09
# frequency band: 1164.06, SINR: 77.88
# frequency band: 1171.88, SINR: 76.72
# frequency band: 1179.69, SINR: 75.63
# frequency band: 1187.50, SINR: 74.61
# frequency band: 1195.31, SINR: 73.68
# frequency band: 1203.12, SINR: 72.86
# frequency band: 1210.94, SINR: 72.18
# frequency band: 1218.75, SINR: 71.67
# frequency band: 1226.56, SINR: 71.35
# frequency band: 1234.38, SINR: 71.24
# frequency band: 1242.19, SINR: 71.35
# frequency band: 1250.00, SINR: 71.68
# frequency band: 1257.81, SINR: 72.20
# frequency band: 1265.62, SINR: 72.89
# frequency band: 1273.44, SINR: 73.73
# frequency band: 1281.25, SINR: 74.68
# frequency band: 1289.06, SINR: 75.74
# frequency band: 1296.88, SINR: 76.87
# frequency band: 1304.69, SINR: 78.07
# frequency band: 1312.50, SINR: 79.34
# frequency band: 1320.31, SINR: 80.69
# frequency band: 1328.12, SINR: 82.13
# frequency band: 1335.94, SINR: 83.70
# frequency band: 1343.75, SINR: 85.43
# frequency band: 1351.56, SINR: 87.40
# frequency band: 1359.38, SINR: 89.75
# frequency band: 1367.19, SINR: 92.71
# frequency band: 1375.00, SINR: 96.85
# frequency band: 1382.81, SINR: 103.88
# frequency band: 1390.62, SINR: 108.27
# frequency band: 1398.44, SINR: 99.72
# frequency band: 1406.25, SINR: 95.30
# frequency band: 1414.06, SINR: 92.53
# frequency band: 1421.88, SINR: 90.59
# frequency band: 1429.69, SINR: 89.17
# frequency band: 1437.50, SINR: 88.12
# frequency band: 1445.31, SINR: 87.36
# frequency band: 1453.12, SINR: 86.83
# frequency band: 1460.94, SINR: 86.52
# frequency band: 1468.75, SINR: 86.40
# frequency band: 1476.56, SINR: 86.45
# frequency band: 1484.38, SINR: 86.67
# frequency band: 1492.19, SINR: 87.06
# frequency band: 1500.00, SINR: 87.60
# frequency band: 1507.81, SINR: 88.31
# frequency band: 1515.62, SINR: 89.17
# frequency band: 1523.44, SINR: 90.20
# frequency band: 1531.25, SINR: 91.39
# frequency band: 1539.06, SINR: 92.74
# frequency band: 1546.88, SINR: 94.22
# frequency band: 1554.69, SINR: 95.73
# frequency band: 1562.50, SINR: 97.08
# frequency band: 1570.31, SINR: 97.95
# frequency band: 1578.12, SINR: 98.14
# frequency band: 1585.94, SINR: 97.74
# frequency band: 1593.75, SINR: 97.07
# frequency band: 1601.56, SINR: 96.39
# frequency band: 1609.38, SINR: 95.82
# frequency band: 1617.19, SINR: 95.44
# frequency band: 1625.00, SINR: 95.23
# frequency band: 1632.81, SINR: 95.22
# frequency band: 1640.62, SINR: 95.40
# frequency band: 1648.44, SINR: 95.77
# frequency band: 1656.25, SINR: 96.32
# frequency band: 1664.06, SINR: 97.06
# frequency band: 1671.88, SINR: 97.99
# frequency band: 1679.69, SINR: 99.10
# frequency band: 1687.50, SINR: 100.36
# frequency band: 1695.31, SINR: 101.69
# frequency band: 1703.12, SINR: 102.86
# frequency band: 1710.94, SINR: 103.58
# frequency band: 1718.75, SINR: 103.61
# frequency band: 1726.56, SINR: 103.04
# frequency band: 1734.38, SINR: 102.21
# frequency band: 1742.19, SINR: 101.36
# frequency band: 1750.00, SINR: 100.64
# frequency band: 1757.81, SINR: 100.10
# frequency band: 1765.62, SINR: 99.76
# frequency band: 1773.44, SINR: 99.63
# frequency band: 1781.25, SINR: 99.71
# frequency band: 1789.06, SINR: 100.00
# frequency band: 1796.88, SINR: 100.51
# frequency band: 1804.69, SINR: 101.23
# frequency band: 1812.50, SINR: 102.12
# frequency band: 1820.31, SINR: 103.04
# frequency band: 1828.12, SINR: 103.69
# frequency band: 1835.94, SINR: 103.62
# frequency band: 1843.75, SINR: 102.63
# frequency band: 1851.56, SINR: 101.06
# frequency band: 1859.38, SINR: 99.33
# frequency band: 1867.19, SINR: 97.67
# frequency band: 1875.00, SINR: 96.17
# frequency band: 1882.81, SINR: 94.84
# frequency band: 1890.62, SINR: 93.67
# frequency band: 1898.44, SINR: 92.65
# frequency band: 1906.25, SINR: 91.76
# frequency band: 1914.06, SINR: 91.00
# frequency band: 1921.88, SINR: 90.37
# frequency band: 1929.69, SINR: 89.84
# frequency band: 1937.50, SINR: 89.42
# frequency band: 1945.31, SINR: 89.11
# frequency band: 1953.12, SINR: 88.91
# frequency band: 1960.94, SINR: 88.81
# frequency band: 1968.75, SINR: 88.83
# frequency band: 1976.56, SINR: 88.95
# frequency band: 1984.38, SINR: 89.19
# frequency band: 1992.19, SINR: 89.53
# frequency band: 2000.00, SINR: 89.97
# frequency band: 2007.81, SINR: 90.48
# frequency band: 2015.62, SINR: 91.02
# frequency band: 2023.44, SINR: 91.46
# frequency band: 2031.25, SINR: 91.65
# frequency band: 2039.06, SINR: 91.41
# frequency band: 2046.88, SINR: 90.67
# frequency band: 2054.69, SINR: 89.52
# frequency band: 2062.50, SINR: 88.15
# frequency band: 2070.31, SINR: 86.70
# frequency band: 2078.12, SINR: 85.29
# frequency band: 2085.94, SINR: 83.94
# frequency band: 2093.75, SINR: 82.70
# frequency band: 2101.56, SINR: 81.57
# frequency band: 2109.38, SINR: 80.56
# frequency band: 2117.19, SINR: 79.68
# frequency band: 2125.00, SINR: 78.93
# frequency band: 2132.81, SINR: 78.32
# frequency band: 2140.62, SINR: 77.86
# frequency band: 2148.44, SINR: 77.56
# frequency band: 2156.25, SINR: 77.40
# frequency band: 2164.06, SINR: 77.37
# frequency band: 2171.88, SINR: 77.44
# frequency band: 2179.69, SINR: 77.55
# frequency band: 2187.50, SINR: 77.63
# frequency band: 2195.31, SINR: 77.59
# frequency band: 2203.12, SINR: 77.40
# frequency band: 2210.94, SINR: 77.08
# frequency band: 2218.75, SINR: 76.68
# frequency band: 2226.56, SINR: 76.30
# frequency band: 2234.38, SINR: 76.00
# frequency band: 2242.19, SINR: 75.81
# frequency band: 2250.00, SINR: 75.76
# frequency band: 2257.81, SINR: 75.84
# frequency band: 2265.62, SINR: 76.02
# frequency band: 2273.44, SINR: 76.27
# frequency band: 2281.25, SINR: 76.56
# frequency band: 2289.06, SINR: 76.84
# frequency band: 2296.88, SINR: 77.07
# frequency band: 2304.69, SINR: 77.21
# frequency band: 2312.50, SINR: 77.25
# frequency band: 2320.31, SINR: 77.16
# frequency band: 2328.12, SINR: 76.96
# frequency band: 2335.94, SINR: 76.65
# frequency band: 2343.75, SINR: 76.26
# frequency band: 2351.56, SINR: 75.81
# frequency band: 2359.38, SINR: 75.32
# frequency band: 2367.19, SINR: 74.80
# frequency band: 2375.00, SINR: 74.29
# frequency band: 2382.81, SINR: 73.80
# frequency band: 2390.62, SINR: 73.35
# frequency band: 2398.44, SINR: 72.96
# frequency band: 2406.25, SINR: 72.65
# frequency band: 2414.06, SINR: 72.45
# frequency band: 2421.88, SINR: 72.37
# frequency band: 2429.69, SINR: 72.42
# frequency band: 2437.50, SINR: 72.63
# frequency band: 2445.31, SINR: 72.99
# frequency band: 2453.12, SINR: 73.51
# frequency band: 2460.94, SINR: 74.17
# frequency band: 2468.75, SINR: 74.98
# frequency band: 2476.56, SINR: 75.92
# frequency band: 2484.38, SINR: 76.98
# frequency band: 2492.19, SINR: 78.15
# frequency band: 2500.00, SINR: 79.45
# frequency band: 2507.81, SINR: 80.87
# frequency band: 2515.62, SINR: 82.45
# frequency band: 2523.44, SINR: 84.23
# frequency band: 2531.25, SINR: 86.30
# frequency band: 2539.06, SINR: 88.83
# frequency band: 2546.88, SINR: 92.19
# frequency band: 2554.69, SINR: 97.40
# frequency band: 2562.50, SINR: 110.19
# frequency band: 2570.31, SINR: 101.46
# frequency band: 2578.12, SINR: 94.34
# frequency band: 2585.94, SINR: 90.37
# frequency band: 2593.75, SINR: 87.55
# frequency band: 2601.56, SINR: 85.32
# frequency band: 2609.38, SINR: 83.42
# frequency band: 2617.19, SINR: 81.75
# frequency band: 2625.00, SINR: 80.22
# frequency band: 2632.81, SINR: 78.81
# frequency band: 2640.62, SINR: 77.50
# frequency band: 2648.44, SINR: 76.26
# frequency band: 2656.25, SINR: 75.10
# frequency band: 2664.06, SINR: 74.03
# frequency band: 2671.88, SINR: 73.06
# frequency band: 2679.69, SINR: 72.21
# frequency band: 2687.50, SINR: 71.50
# frequency band: 2695.31, SINR: 70.94
# frequency band: 2703.12, SINR: 70.55
# frequency band: 2710.94, SINR: 70.34
# frequency band: 2718.75, SINR: 70.31
# frequency band: 2726.56, SINR: 70.44
# frequency band: 2734.38, SINR: 70.72
# frequency band: 2742.19, SINR: 71.12
# frequency band: 2750.00, SINR: 71.61
# frequency band: 2757.81, SINR: 72.17
# frequency band: 2765.62, SINR: 72.78
# frequency band: 2773.44, SINR: 73.41
# frequency band: 2781.25, SINR: 74.05
# frequency band: 2789.06, SINR: 74.68
# frequency band: 2796.88, SINR: 75.30
# frequency band: 2804.69, SINR: 75.90
# frequency band: 2812.50, SINR: 76.46
# frequency band: 2820.31, SINR: 76.99
# frequency band: 2828.12, SINR: 77.49
# frequency band: 2835.94, SINR: 77.94
# frequency band: 2843.75, SINR: 78.35
# frequency band: 2851.56, SINR: 78.73
# frequency band: 2859.38, SINR: 79.06
# frequency band: 2867.19, SINR: 79.35
# frequency band: 2875.00, SINR: 79.60
# frequency band: 2882.81, SINR: 79.81
# frequency band: 2890.62, SINR: 79.99
# frequency band: 2898.44, SINR: 80.13
# frequency band: 2906.25, SINR: 80.25
# frequency band: 2914.06, SINR: 80.33
# frequency band: 2921.88, SINR: 80.39
# frequency band: 2929.69, SINR: 80.43
# frequency band: 2937.50, SINR: 80.46
# frequency band: 2945.31, SINR: 80.48
# frequency band: 2953.12, SINR: 80.50
# frequency band: 2960.94, SINR: 80.53
# frequency band: 2968.75, SINR: 80.58
# frequency band: 2976.56, SINR: 80.65
# frequency band: 2984.38, SINR: 80.75
# frequency band: 2992.19, SINR: 80.90
# frequency band: 3000.00, SINR: 81.08
# frequency band: 3007.81, SINR: 81.32
# frequency band: 3015.62, SINR: 81.62
# frequency band: 3023.44, SINR: 81.97
# frequency band: 3031.25, SINR: 82.38
# frequency band: 3039.06, SINR: 82.86
# frequency band: 3046.88, SINR: 83.40
# frequency band: 3054.69, SINR: 84.00
# frequency band: 3062.50, SINR: 84.67
# frequency band: 3070.31, SINR: 85.39
# frequency band: 3078.12, SINR: 86.16
# frequency band: 3085.94, SINR: 86.96
# frequency band: 3093.75, SINR: 87.78
# frequency band: 3101.56, SINR: 88.59
# frequency band: 3109.38, SINR: 89.33
# frequency band: 3117.19, SINR: 89.94
# frequency band: 3125.00, SINR: 90.35
# frequency band: 3132.81, SINR: 90.53
# frequency band: 3140.62, SINR: 90.47
# frequency band: 3148.44, SINR: 90.20
# frequency band: 3156.25, SINR: 89.80
# frequency band: 3164.06, SINR: 89.32
# frequency band: 3171.88, SINR: 88.83
# frequency band: 3179.69, SINR: 88.36
# frequency band: 3187.50, SINR: 87.93
# frequency band: 3195.31, SINR: 87.55
# frequency band: 3203.12, SINR: 87.23
# frequency band: 3210.94, SINR: 86.97
# frequency band: 3218.75, SINR: 86.78
# frequency band: 3226.56, SINR: 86.64
# frequency band: 3234.38, SINR: 86.55
# frequency band: 3242.19, SINR: 86.50
# frequency band: 3250.00, SINR: 86.50
# frequency band: 3257.81, SINR: 86.53
# frequency band: 3265.62, SINR: 86.58
# frequency band: 3273.44, SINR: 86.66
# frequency band: 3281.25, SINR: 86.76
# frequency band: 3289.06, SINR: 86.88
# frequency band: 3296.88, SINR: 87.02
# frequency band: 3304.69, SINR: 87.17
# frequency band: 3312.50, SINR: 87.35
# frequency band: 3320.31, SINR: 87.55
# frequency band: 3328.12, SINR: 87.79
# frequency band: 3335.94, SINR: 88.06
# frequency band: 3343.75, SINR: 88.37
# frequency band: 3351.56, SINR: 88.74
# frequency band: 3359.38, SINR: 89.15
# frequency band: 3367.19, SINR: 89.61
# frequency band: 3375.00, SINR: 90.13
# frequency band: 3382.81, SINR: 90.70
# frequency band: 3390.62, SINR: 91.30
# frequency band: 3398.44, SINR: 91.92
# frequency band: 3406.25, SINR: 92.54
# frequency band: 3414.06, SINR: 93.10
# frequency band: 3421.88, SINR: 93.57
# frequency band: 3429.69, SINR: 93.91
# frequency band: 3437.50, SINR: 94.09
# frequency band: 3445.31, SINR: 94.13
# frequency band: 3453.12, SINR: 94.06
# frequency band: 3460.94, SINR: 93.94
# frequency band: 3468.75, SINR: 93.82
# frequency band: 3476.56, SINR: 93.76
# frequency band: 3484.38, SINR: 93.80
# frequency band: 3492.19, SINR: 93.98
# frequency band: 3500.00, SINR: 94.33
# frequency band: 3507.81, SINR: 94.89
# frequency band: 3515.62, SINR: 95.70
# frequency band: 3523.44, SINR: 96.76
# frequency band: 3531.25, SINR: 98.03
# frequency band: 3539.06, SINR: 99.21
# frequency band: 3546.88, SINR: 99.50
# frequency band: 3554.69, SINR: 98.27
# frequency band: 3562.50, SINR: 96.06
# frequency band: 3570.31, SINR: 93.69
# frequency band: 3578.12, SINR: 91.49
# frequency band: 3585.94, SINR: 89.50
# frequency band: 3593.75, SINR: 87.71
# frequency band: 3601.56, SINR: 86.08
# frequency band: 3609.38, SINR: 84.58
# frequency band: 3617.19, SINR: 83.19
# frequency band: 3625.00, SINR: 81.88
# frequency band: 3632.81, SINR: 80.64
# frequency band: 3640.62, SINR: 79.47
# frequency band: 3648.44, SINR: 78.36
# frequency band: 3656.25, SINR: 77.31
# frequency band: 3664.06, SINR: 76.33
# frequency band: 3671.88, SINR: 75.44
# frequency band: 3679.69, SINR: 74.64
# frequency band: 3687.50, SINR: 73.97
# frequency band: 3695.31, SINR: 73.44
# frequency band: 3703.12, SINR: 73.08
# frequency band: 3710.94, SINR: 72.90
# frequency band: 3718.75, SINR: 72.91
# frequency band: 3726.56, SINR: 73.11
# frequency band: 3734.38, SINR: 73.51
# frequency band: 3742.19, SINR: 74.07
# frequency band: 3750.00, SINR: 74.80
# frequency band: 3757.81, SINR: 75.66
# frequency band: 3765.62, SINR: 76.63
# frequency band: 3773.44, SINR: 77.72
# frequency band: 3781.25, SINR: 78.91
# frequency band: 3789.06, SINR: 80.20
# frequency band: 3796.88, SINR: 81.61
# frequency band: 3804.69, SINR: 83.17
# frequency band: 3812.50, SINR: 84.92
# frequency band: 3820.31, SINR: 86.93
# frequency band: 3828.12, SINR: 89.36
# frequency band: 3835.94, SINR: 92.46
# frequency band: 3843.75, SINR: 96.89
# frequency band: 3851.56, SINR: 104.73
# frequency band: 3859.38, SINR: 106.35
# frequency band: 3867.19, SINR: 98.42
# frequency band: 3875.00, SINR: 94.36
# frequency band: 3882.81, SINR: 91.81
# frequency band: 3890.62, SINR: 90.04
# frequency band: 3898.44, SINR: 88.78
# frequency band: 3906.25, SINR: 87.89
# frequency band: 3914.06, SINR: 87.29
# frequency band: 3921.88, SINR: 86.93
# frequency band: 3929.69, SINR: 86.81
# frequency band: 3937.50, SINR: 86.88
# frequency band: 3945.31, SINR: 87.15
# frequency band: 3953.12, SINR: 87.61
# frequency band: 3960.94, SINR: 88.25
# frequency band: 3968.75, SINR: 89.07
# frequency band: 3976.56, SINR: 90.07
# frequency band: 3984.38, SINR: 91.25
# frequency band: 3992.19, SINR: 92.58
# frequency band: 4000.00, SINR: 94.00
# average SINR: 87.07
# frequency band: 0.00, SINR: 0.88
# frequency band: 7.81, SINR: 2.70
# frequency band: 15.62, SINR: 6.89
# frequency band: 23.44, SINR: 11.73
# frequency band: 31.25, SINR: 16.49
# frequency band: 39.06, SINR: 20.96
# frequency band: 46.88, SINR: 25.11
# frequency band: 54.69, SINR: 28.94
# frequency band: 62.50, SINR: 32.50
# frequency band: 70.31, SINR: 35.79
# frequency band: 78.12, SINR: 38.87
# frequency band: 85.94, SINR: 41.73
# frequency band: 93.75, SINR: 44.43
# frequency band: 101.56, SINR: 46.96
# frequency band: 109.38, SINR: 49.35
# frequency band: 117.19, SINR: 51.62
# frequency band: 125.00, SINR: 53.78
# frequency band: 132.81, SINR: 55.84
# frequency band: 140.62, SINR: 57.82
# frequency band: 148.44, SINR: 59.72
# frequency band: 156.25, SINR: 61.55
# frequency band: 164.06, SINR: 63.32
# frequency band: 171.88, SINR: 65.05
# frequency band: 179.69, SINR: 66.73
# frequency band: 187.50, SINR: 68.38
# frequency band: 195.31, SINR: 70.00
# frequency band: 203.12, SINR: 71.60
# frequency band: 210.94, SINR: 73.20
# frequency band: 218.75, SINR: 74.79
# frequency band: 226.56, SINR: 76.40
# frequency band: 234.38, SINR: 78.03
# frequency band: 242.19, SINR: 79.70
# frequency band: 250.00, SINR: 81.44
# frequency band: 257.81, SINR: 83.27
# frequency band: 265.62, SINR: 85.23
# frequency band: 273.44, SINR: 87.38
# frequency band: 281.25, SINR: 89.83
# frequency band: 289.06, SINR: 92.74
# frequency band: 296.88, SINR: 96.50
# frequency band: 304.69, SINR: 102.17
# frequency band: 312.50, SINR: 116.56
# frequency band: 320.31, SINR: 107.06
# frequency band: 328.12, SINR: 100.36
# frequency band: 335.94, SINR: 96.90
# frequency band: 343.75, SINR: 94.62
# frequency band: 351.56, SINR: 92.96
# frequency band: 359.38, SINR: 91.66
# frequency band: 367.19, SINR: 90.62
# frequency band: 375.00, SINR: 89.74
# frequency band: 382.81, SINR: 89.01
# frequency band: 390.62, SINR: 88.37
# frequency band: 398.44, SINR: 87.82
# frequency band: 406.25, SINR: 87.34
# frequency band: 414.06, SINR: 86.92
# frequency band: 421.88, SINR: 86.56
# frequency band: 429.69, SINR: 86.25
# frequency band: 437.50, SINR: 85.98
# frequency band: 445.31, SINR: 85.77
# frequency band: 453.12, SINR: 85.61
# frequency band: 460.94, SINR: 85.50
# frequency band: 468.75, SINR: 85.44
# frequency band: 476.56, SINR: 85.44
# frequency band: 484.38, SINR: 85.51
# frequency band: 492.19, SINR: 85.65
# frequency band: 500.00, SINR: 85.85
# frequency band: 507.81, SINR: 86.14
# frequency band: 515.62, SINR: 86.51
# frequency band: 523.44, SINR: 86.98
# frequency band: 531.25, SINR: 87.54
# frequency band: 539.06, SINR: 88.20
# frequency band: 546.88, SINR: 88.98
# frequency band: 554.69, SINR: 89.87
# frequency band: 562.50, SINR: 90.91
# frequency band: 570.31, SINR: 92.09
# frequency band: 578.12, SINR: 93.46
# frequency band: 585.94, SINR: 95.05
# frequency band: 593.75, SINR: 96.93
# frequency band: 601.56, SINR: 99.21
# frequency band: 609.38, SINR: 102.14
# frequency band: 617.19, SINR: 106.23
# frequency band: 625.00, SINR: 113.20
# frequency band: 632.81, SINR: 120.50
# frequency band: 640.62, SINR: 110.32
# frequency band: 648.44, SINR: 105.62
# frequency band: 656.25, SINR: 102.75
# frequency band: 664.06, SINR: 100.74
# frequency band: 671.88, SINR: 99.23
# frequency band: 679.69, SINR: 98.02
# frequency band: 687.50, SINR: 97.05
# frequency band: 695.31, SINR: 96.23
# frequency band: 703.12, SINR: 95.54
# frequency band: 710.94, SINR: 94.95
# frequency band: 718.75, SINR: 94.44
# frequency band: 726.56, SINR: 94.00
# frequency band: 734.38, SINR: 93.62
# frequency band: 742.19, SINR: 93.29
# frequency band: 750.00, SINR: 93.01
# frequency band: 757.81, SINR: 92.77
# frequency band: 765.62, SINR: 92.58
# frequency band: 773.44, SINR: 92.44
# frequency band: 781.25, SINR: 92.34
# frequency band: 789.06, SINR: 92.30
# frequency band: 796.88, SINR: 92.31
# frequency band: 804.69, SINR: 92.38
# frequency band: 812.50, SINR: 92.51
# frequency band: 820.31, SINR: 92.72
# frequency band: 828.12, SINR: 93.01
# frequency band: 835.94, SINR: 93.38
# frequency band: 843.75, SINR: 93.85
# frequency band: 851.56, SINR: 94.42
# frequency band: 859.38, SINR: 95.11
# frequency band: 867.19, SINR: 95.92
# frequency band: 875.00, SINR: 96.87
# frequency band: 882.81, SINR: 97.98
# frequency band: 890.62, SINR: 99.26
# frequency band: 898.44, SINR: 100.76
# frequency band: 906.25, SINR: 102.53
# frequency band: 914.06, SINR: 104.64
# frequency band: 921.88, SINR: 107.26
# frequency band: 929.69, SINR: 110.70
# frequency band: 937.50, SINR: 115.61
# frequency band: 945.31, SINR: 121.92
# frequency band: 953.12, SINR: 118.53
# frequency band: 960.94, SINR: 113.65
# frequency band: 968.75, SINR: 110.57
# frequency band: 976.56, SINR: 108.45
# frequency band: 984.38, SINR: 106.89
# frequency band: 992.19, SINR: 105.69
# frequency band: 1000.00, SINR: 104.72
# frequency band: 1007.81, SINR: 103.93
# frequency band: 1015.62, SINR: 103.26
# frequency band: 1023.44, SINR: 102.69
# frequency band: 1031.25, SINR: 102.19
# frequency band: 1039.06, SINR: 101.75
# frequency band: 1046.88, SINR: 101.34
# frequency band: 1054.69, SINR: 100.97
# frequency band: 1062.50, SINR: 100.62
# frequency band: 1070.31, SINR: 100.28
# frequency band: 1078.12, SINR: 99.95
# frequency band: 1085.94, SINR: 99.62
# frequency band: 1093.75, SINR: 99.28
# frequency band: 1101.56, SINR: 98.94
# frequency band: 1109.38, SINR: 98.57
# frequency band: 1117.19, SINR: 98.18
# frequency band: 1125.00, SINR: 97.76
# frequency band: 1132.81, SINR: 97.31
# frequency band: 1140.62, SINR: 96.81
# frequency band: 1148.44, SINR: 96.24
# frequency band: 1156.25, SINR: 95.61
# frequency band: 1164.06, SINR: 94.89
# frequency band: 1171.88, SINR: 94.06
# frequency band: 1179.69, SINR: 93.09
# frequency band: 1187.50, SINR: 91.93
# frequency band: 1195.31, SINR: 90.53
# frequency band: 1203.12, SINR: 88.81
# frequency band: 1210.94, SINR: 86.65
# frequency band: 1218.75, SINR: 83.98
# frequency band: 1226.56, SINR: 81.11
# frequency band: 1234.38, SINR: 80.26
# frequency band: 1242.19, SINR: 85.53
# frequency band: 1250.00, SINR: 95.01
# frequency band: 1257.81, SINR: 101.81
# frequency band: 1265.62, SINR: 103.09
# frequency band: 1273.44, SINR: 103.76
# frequency band: 1281.25, SINR: 104.79
# frequency band: 1289.06, SINR: 106.06
# frequency band: 1296.88, SINR: 107.50
# frequency band: 1304.69, SINR: 109.06
# frequency band: 1312.50, SINR: 110.74
# frequency band: 1320.31, SINR: 112.57
# frequency band: 1328.12, SINR: 114.56
# frequency band: 1335.94, SINR: 116.72
# frequency band: 1343.75, SINR: 118.96
# frequency band: 1351.56, SINR: 120.89
# frequency band: 1359.38, SINR: 121.74
# frequency band: 1367.19, SINR: 121.10
# frequency band: 1375.00, SINR: 119.65
# frequency band: 1382.81, SINR: 118.08
# frequency band: 1390.62, SINR: 116.65
# frequency band: 1398.44, SINR: 115.40
# frequency band: 1406.25, SINR: 114.32
# frequency band: 1414.06, SINR: 113.37
# frequency band: 1421.88, SINR: 112.54
# frequency band: 1429.69, SINR: 111.81
# frequency band: 1437.50, SINR: 111.17
# frequency band: 1445.31, SINR: 110.59
# frequency band: 1453.12, SINR: 110.09
# frequency band: 1460.94, SINR: 109.64
# frequency band: 1468.75, SINR: 109.25
# frequency band: 1476.56, SINR: 108.92
# frequency band: 1484.38, SINR: 108.64
# frequency band: 1492.19, SINR: 108.43
# frequency band: 1500.00, SINR: 108.29
# frequency band: 1507.81, SINR: 108.23
# frequency band: 1515.62, SINR: 108.25
# frequency band: 1523.44, SINR: 108.37
# frequency band: 1531.25, SINR: 108.61
# frequency band: 1539.06, SINR: 108.97
# frequency band: 1546.88, SINR: 109.49
# frequency band: 1554.69, SINR: 110.16
# frequency band: 1562.50, SINR: 110.96
# frequency band: 1570.31, SINR: 111.75
# frequency band: 1578.12, SINR: 112.22
# frequency band: 1585.94, SINR: 111.93
# frequency band: 1593.75, SINR: 110.74
# frequency band: 1601.56, SINR: 108.99
# frequency band: 1609.38, SINR: 107.12
# frequency band: 1617.19, SINR: 105.34
# frequency band: 1625.00, SINR: 103.75
# frequency band: 1632.81, SINR: 102.34
# frequency band: 1640.62, SINR: 101.12
# frequency band: 1648.44, SINR: 100.06
# frequency band: 1656.25, SINR: 99.15
# frequency band: 1664.06, SINR: 98.36
# frequency band: 1671.88, SINR: 97.68
# frequency band: 1679.69, SINR: 97.10
# frequency band: 1687.50, SINR: 96.60
# frequency band: 1695.31, SINR: 96.18
# frequency band: 1703.12, SINR: 95.81
# frequency band: 1710.94, SINR: 95.51
# frequency band: 1718.75, SINR: 95.24
# frequency band: 1726.56, SINR: 95.02
# frequency band: 1734.38, SINR: 94.83
# frequency band: 1742.19, SINR: 94.68
# frequency band: 1750.00, SINR: 94.55
# frequency band: 1757.81, SINR: 94.44
# frequency band: 1765.62, SINR: 94.36
# frequency band: 1773.44, SINR: 94.29
# frequency band: 1781.25, SINR: 94.24
# frequency band: 1789.06, SINR: 94.22
# frequency band: 1796.88, SINR: 94.21
# frequency band: 1804.69, SINR: 94.21
# frequency band: 1812.50, SINR: 94.24
# frequency band: 1820.31, SINR: 94.28
# frequency band: 1828.12, SINR: 94.33
# frequency band: 1835.94, SINR: 94.39
# frequency band: 1843.75, SINR: 94.45
# frequency band: 1851.56, SINR: 94.51
# frequency band: 1859.38, SINR: 94.54
# frequency band: 1867.19, SINR: 94.53
# frequency band: 1875.00, SINR: 94.47
# frequency band: 1882.81, SINR: 94.31
# frequency band: 1890.62, SINR: 94.05
# frequency band: 1898.44, SINR: 93.66
# frequency band: 1906.25, SINR: 93.15
# frequency band: 1914.06, SINR: 92.53
# frequency band: 1921.88, SINR: 91.83
# frequency band: 1929.69, SINR: 91.07
# frequency band: 1937.50, SINR: 90.29
# frequency band: 1945.31, SINR: 89.50
# frequency band: 1953.12, SINR: 88.73
# frequency band: 1960.94, SINR: 88.00
# frequency band: 1968.75, SINR: 87.30
# frequency band: 1976.56, SINR: 86.65
# frequency band: 1984.38, SINR: 86.04
# frequency band: 1992.19, SINR: 85.48
# frequency band: 2000.00, SINR: 84.96
# frequency band: 2007.81, SINR: 84.47
# frequency band: 2015.62, SINR: 84.03
# frequency band: 2023.44, SINR: 83.61
# frequency band: 2031.25, SINR: 83.22
# frequency band: 2039.06, SINR: 82.85
# frequency band: 2046.88, SINR: 82.49
# frequency band: 2054.69, SINR: 82.15
# frequency band: 2062.50, SINR: 81.83
# frequency band: 2070.31, SINR: 81.50
# frequency band: 2078.12, SINR: 81.19
# frequency band: 2085.94, SINR: 80.87
# frequency band: 2093.75, SINR: 80.55
# frequency band: 2101.56, SINR: 80.23
# frequency band: 2109.38, SINR: 79.91
# frequency band: 2117.19, SINR: 79.58
# frequency band: 2125.00, SINR: 79.25
# frequency band: 2132.81, SINR: 78.92
# frequency band: 2140.62, SINR: 78.58
# frequency band: 2148.44, SINR: 78.24
# frequency band: 2156.25, SINR: 77.91
# frequency band: 2164.06, SINR: 77.58
# frequency band: 2171.88, SINR: 77.26
# frequency band: 2179.69, SINR: 76.95
# frequency band: 2187.50, SINR: 76.67
# frequency band: 2195.31, SINR: 76.42
# frequency band: 2203.12, SINR: 76.22
# frequency band: 2210.94, SINR: 76.06
# frequency band: 2218.75, SINR: 75.96
# frequency band: 2226.56, SINR: 75.92
# frequency band: 2234.38, SINR: 75.97
# frequency band: 2242.19, SINR: 76.10
# frequency band: 2250.00, SINR: 76.32
# frequency band: 2257.81, SINR: 76.63
# frequency band: 2265.62, SINR: 77.03
# frequency band: 2273.44, SINR: 77.51
# frequency band: 2281.25, SINR: 78.06
# frequency band: 2289.06, SINR: 78.68
# frequency band: 2296.88, SINR: 79.34
# frequency band: 2304.69, SINR: 80.05
# frequency band: 2312.50, SINR: 80.78
# frequency band: 2320.31, SINR: 81.53
# frequency band: 2328.12, SINR: 82.28
# frequency band: 2335.94, SINR: 83.02
# frequency band: 2343.75, SINR: 83.75
# frequency band: 2351.56, SINR: 84.44
# frequency band: 2359.38, SINR: 85.10
# frequency band: 2367.19, SINR: 85.72
# frequency band: 2375.00, SINR: 86.29
# frequency band: 2382.81, SINR: 86.81
# frequency band: 2390.62, SINR: 87.27
# frequency band: 2398.44, SINR: 87.68
# frequency band: 2406.25, SINR: 88.03
# frequency band: 2414.06, SINR: 88.33
# frequency band: 2421.88, SINR: 88.58
# frequency band: 2429.69, SINR: 88.77
# frequency band: 2437.50, SINR: 88.92
# frequency band: 2445.31, SINR: 89.02
# frequency band: 2453.12, SINR: 89.08
# frequency band: 2460.94, SINR: 89.10
# frequency band: 2468.75, SINR: 89.08
# frequency band: 2476.56, SINR: 89.03
# frequency band: 2484.38, SINR: 88.94
# frequency band: 2492.19, SINR: 88.83
# frequency band: 2500.00, SINR: 88.68
# frequency band: 2507.81, SINR: 88.51
# frequency band: 2515.62, SINR: 88.31
# frequency band: 2523.44, SINR: 88.08
# frequency band: 2531.25, SINR: 87.81
# frequency band: 2539.06, SINR: 87.52
# frequency band: 2546.88, SINR: 87.20
# frequency band: 2554.69, SINR: 86.84
# frequency band: 2562.50, SINR: 86.45
# frequency band: 2570.31, SINR: 86.02
# frequency band: 2578.12, SINR: 85.55
# frequency band: 2585.94, SINR: 85.04
# frequency band: 2593.75, SINR: 84.49
# frequency band: 2601.56, SINR: 83.89
# frequency band: 2609.38, SINR: 83.25
# frequency band: 2617.19, SINR: 82.57
# frequency band: 2625.00, SINR: 81.85
# frequency band: 2632.81, SINR: 81.09
# frequency band: 2640.62, SINR: 80.31
# frequency band: 2648.44, SINR: 79.51
# frequency band: 2656.25, SINR: 78.71
# frequency band: 2664.06, SINR: 77.93
# frequency band: 2671.88, SINR: 77.17
# frequency band: 2679.69, SINR: 76.46
# frequency band: 2687.50, SINR: 75.82
# frequency band: 2695.31, SINR: 75.25
# frequency band: 2703.12, SINR: 74.78
# frequency band: 2710.94, SINR: 74.40
# frequency band: 2718.75, SINR: 74.11
# frequency band: 2726.56, SINR: 73.92
# frequency band: 2734.38, SINR: 73.82
# frequency band: 2742.19, SINR: 73.79
# frequency band: 2750.00, SINR: 73.83
# frequency band: 2757.81, SINR: 73.92
# frequency band: 2765.62, SINR: 74.05
# frequency band: 2773.44, SINR: 74.21
# frequency band: 2781.25, SINR: 74.39
# frequency band: 2789.06, SINR: 74.59
# frequency band: 2796.88, SINR: 74.79
# frequency band: 2804.69, SINR: 74.99
# frequency band: 2812.50, SINR: 75.19
# frequency band: 2820.31, SINR: 75.38
# frequency band: 2828.12, SINR: 75.56
# frequency band: 2835.94, SINR: 75.74
# frequency band: 2843.75, SINR: 75.91
# frequency band: 2851.56, SINR: 76.07
# frequency band: 2859.38, SINR: 76.22
# frequency band: 2867.19, SINR: 76.37
# frequency band: 2875.00, SINR: 76.51
# frequency band: 2882.81, SINR: 76.66
# frequency band: 2890.62, SINR: 76.80
# frequency band: 2898.44, SINR: 76.94
# frequency band: 2906.25, SINR: 77.09
# frequency band: 2914.06, SINR: 77.25
# frequency band: 2921.88, SINR: 77.42
# frequency band: 2929.69, SINR: 77.61
# frequency band: 2937.50, SINR: 77.83
# frequency band: 2945.31, SINR: 78.07
# frequency band: 2953.12, SINR: 78.33
# frequency band: 2960.94, SINR: 78.64
# frequency band: 2968.75, SINR: 78.98
# frequency band: 2976.56, SINR: 79.37
# frequency band: 2984.38, SINR: 79.80
# frequency band: 2992.19, SINR: 80.28
# frequency band: 3000.00, SINR: 80.81
# frequency band: 3007.81, SINR: 81.39
# frequency band: 3015.62, SINR: 82.02
# frequency band: 3023.44, SINR: 82.69
# frequency band: 3031.25, SINR: 83.40
# frequency band: 3039.06, SINR: 84.13
# frequency band: 3046.88, SINR: 84.87
# frequency band: 3054.69, SINR: 85.58
# frequency band: 3062.50, SINR: 86.25
# frequency band: 3070.31, SINR: 86.84
# frequency band: 3078.12, SINR: 87.32
# frequency band: 3085.94, SINR: 87.66
# frequency band: 3093.75, SINR: 87.86
# frequency band: 3101.56, SINR: 87.92
# frequency band: 3109.38, SINR: 87.87
# frequency band: 3117.19, SINR: 87.72
# frequency band: 3125.00, SINR: 87.51
# frequency band: 3132.81, SINR: 87.25
# frequency band: 3140.62, SINR: 86.98
# frequency band: 3148.44, SINR: 86.69
# frequency band: 3156.25, SINR: 86.41
# frequency band: 3164.06, SINR: 86.13
# frequency band: 3171.88, SINR: 85.86
# frequency band: 3179.69, SINR: 85.60
# frequency band: 3187.50, SINR: 85.36
# frequency band: 3195.31, SINR: 85.13
# frequency band: 3203.12, SINR: 84.92
# frequency band: 3210.94, SINR: 84.73
# frequency band: 3218.75, SINR: 84.55
# frequency band: 3226.56, SINR: 84.39
# frequency band: 3234.38, SINR: 84.26
# frequency band: 3242.19, SINR: 84.14
# frequency band: 3250.00, SINR: 84.05
# frequency band: 3257.81, SINR: 84.00
# frequency band: 3265.62, SINR: 83.97
# frequency band: 3273.44, SINR: 83.98
# frequency band: 3281.25, SINR: 84.03
# frequency band: 3289.06, SINR: 84.13
# frequency band: 3296.88, SINR: 84.28
# frequency band: 3304.69, SINR: 84.48
# frequency band: 3312.50, SINR: 84.74
# frequency band: 3320.31, SINR: 85.07
# frequency band: 3328.12, SINR: 85.47
# frequency band: 3335.94, SINR: 85.95
# frequency band: 3343.75, SINR: 86.50
# frequency band: 3351.56, SINR: 87.13
# frequency band: 3359.38, SINR: 87.84
# frequency band: 3367.19, SINR: 88.64
# frequency band: 3375.00, SINR: 89.52
# frequency band: 3382.81, SINR: 90.47
# frequency band: 3390.62, SINR: 91.49
# frequency band: 3398.44, SINR: 92.55
# frequency band: 3406.25, SINR: 93.63
# frequency band: 3414.06, SINR: 94.68
# frequency band: 3421.88, SINR: 95.61
# frequency band: 3429.69, SINR: 96.34
# frequency band: 3437.50, SINR: 96.77
# frequency band: 3445.31, SINR: 96.87
# frequency band: 3453.12, SINR: 96.68
# frequency band: 3460.94, SINR: 96.28
# frequency band: 3468.75, SINR: 95.75
# frequency band: 3476.56, SINR: 95.16
# frequency band: 3484.38, SINR: 94.55
# frequency band: 3492.19, SINR: 93.96
# frequency band: 3500.00, SINR: 93.37
# frequency band: 3507.81, SINR: 92.81
# frequency band: 3515.62, SINR: 92.27
# frequency band: 3523.44, SINR: 91.74
# frequency band: 3531.25, SINR: 91.22
# frequency band: 3539.06, SINR: 90.71
# frequency band: 3546.88, SINR: 90.20
# frequency band: 3554.69, SINR: 89.68
# frequency band: 3562.50, SINR: 89.15
# frequency band: 3570.31, SINR: 88.60
# frequency band: 3578.12, SINR: 88.04
# frequency band: 3585.94, SINR: 87.44
# frequency band: 3593.75, SINR: 86.81
# frequency band: 3601.56, SINR: 86.14
# frequency band: 3609.38, SINR: 85.41
# frequency band: 3617.19, SINR: 84.63
# frequency band: 3625.00, SINR: 83.77
# frequency band: 3632.81, SINR: 82.82
# frequency band: 3640.62, SINR: 81.77
# frequency band: 3648.44, SINR: 80.59
# frequency band: 3656.25, SINR: 79.27
# frequency band: 3664.06, SINR: 77.77
# frequency band: 3671.88, SINR: 76.08
# frequency band: 3679.69, SINR: 74.21
# frequency band: 3687.50, SINR: 72.25
# frequency band: 3695.31, SINR: 70.54
# frequency band: 3703.12, SINR: 69.87
# frequency band: 3710.94, SINR: 71.20
# frequency band: 3718.75, SINR: 74.66
# frequency band: 3726.56, SINR: 79.29
# frequency band: 3734.38, SINR: 83.97
# frequency band: 3742.19, SINR: 87.69
# frequency band: 3750.00, SINR: 89.87
# frequency band: 3757.81, SINR: 90.87
# frequency band: 3765.62, SINR: 91.38
# frequency band: 3773.44, SINR: 91.75
# frequency band: 3781.25, SINR: 92.10
# frequency band: 3789.06, SINR: 92.46
# frequency band: 3796.88, SINR: 92.84
# frequency band: 3804.69, SINR: 93.22
# frequency band: 3812.50, SINR: 93.62
# frequency band: 3820.31, SINR: 94.01
# frequency band: 3828.12, SINR: 94.40
# frequency band: 3835.94, SINR: 94.78
# frequency band: 3843.75, SINR: 95.16
# frequency band: 3851.56, SINR: 95.53
# frequency band: 3859.38, SINR: 95.89
# frequency band: 3867.19, SINR: 96.24
# frequency band: 3875.00, SINR: 96.58
# frequency band: 3882.81, SINR: 96.91
# frequency band: 3890.62, SINR: 97.22
# frequency band: 3898.44, SINR: 97.51
# frequency band: 3906.25, SINR: 97.79
# frequency band: 3914.06, SINR: 98.03
# frequency band: 3921.88, SINR: 98.24
# frequency band: 3929.69, SINR: 98.41
# frequency band: 3937.50, SINR: 98.53
# frequency band: 3945.31, SINR: 98.58
# frequency band: 3953.12, SINR: 98.55
# frequency band: 3960.94, SINR: 98.44
# frequency band: 3968.75, SINR: 98.22
# frequency band: 3976.56, SINR: 97.89
# frequency band: 3984.38, SINR: 97.45
# frequency band: 3992.19, SINR: 96.91
# frequency band: 4000.00, SINR: 96.28
# average SINR: 88.46
# frequency band: 0.00, SINR: 37.74
# frequency band: 7.81, SINR: 41.38
# frequency band: 15.62, SINR: 47.52
# frequency band: 23.44, SINR: 52.84
# frequency band: 31.25, SINR: 57.15
# frequency band: 39.06, SINR: 60.70
# frequency band: 46.88, SINR: 63.70
# frequency band: 54.69, SINR: 66.29
# frequency band: 62.50, SINR: 68.58
# frequency band: 70.31, SINR: 70.62
# frequency band: 78.12, SINR: 72.49
# frequency band: 85.94, SINR: 74.20
# frequency band: 93.75, SINR: 75.80
# frequency band: 101.56, SINR: 77.31
# frequency band: 109.38, SINR: 78.76
# frequency band: 117.19, SINR: 80.16
# frequency band: 125.00, SINR: 81.53
# frequency band: 132.81, SINR: 82.89
# frequency band: 140.62, SINR: 84.27
# frequency band: 148.44, SINR: 85.68
# frequency band: 156.25, SINR: 87.15
# frequency band: 164.06, SINR: 88.71
# frequency band: 171.88, SINR: 90.41
# frequency band: 179.69, SINR: 92.28
# frequency band: 187.50, SINR: 94.43
# frequency band: 195.31, SINR: 96.96
# frequency band: 203.12, SINR: 100.10
# frequency band: 210.94, SINR: 104.27
# frequency band: 218.75, SINR: 109.83
# frequency band: 226.56, SINR: 111.13
# frequency band: 234.38, SINR: 106.68
# frequency band: 242.19, SINR: 103.46
# frequency band: 250.00, SINR: 101.38
# frequency band: 257.81, SINR: 100.00
# frequency band: 265.62, SINR: 99.08
# frequency band: 273.44, SINR: 98.49
# frequency band: 281.25, SINR: 98.15
# frequency band: 289.06, SINR: 98.02
# frequency band: 296.88, SINR: 98.06
# frequency band: 304.69, SINR: 98.22
# frequency band: 312.50, SINR: 98.48
# frequency band: 320.31, SINR: 98.80
# frequency band: 328.12, SINR: 99.15
# frequency band: 335.94, SINR: 99.47
# frequency band: 343.75, SINR: 99.72
# frequency band: 351.56, SINR: 99.86
# frequency band: 359.38, SINR: 99.85
# frequency band: 367.19, SINR: 99.69
# frequency band: 375.00, SINR: 99.37
# frequency band: 382.81, SINR: 98.90
# frequency band: 390.62, SINR: 98.30
# frequency band: 398.44, SINR: 97.60
# frequency band: 406.25, SINR: 96.83
# frequency band: 414.06, SINR: 96.01
# frequency band: 421.88, SINR: 95.16
# frequency band: 429.69, SINR: 94.32
# frequency band: 437.50, SINR: 93.51
# frequency band: 445.31, SINR: 92.75
# frequency band: 453.12, SINR: 92.05
# frequency band: 460.94, SINR: 91.43
# frequency band: 468.75, SINR: 90.89
# frequency band: 476.56, SINR: 90.46
# frequency band: 484.38, SINR: 90.13
# frequency band: 492.19, SINR: 89.92
# frequency band: 500.00, SINR: 89.83
# frequency band: 507.81, SINR: 89.87
# frequency band: 515.62, SINR: 90.06
# frequency band: 523.44, SINR: 90.40
# frequency band: 531.25, SINR: 90.91
# frequency band: 539.06, SINR: 91.62
# frequency band: 546.88, SINR: 92.57
# frequency band: 554.69, SINR: 93.80
# frequency band: 562.50, SINR: 95.41
# frequency band: 570.31, SINR: 97.56
# frequency band: 578.12, SINR: 100.58
# frequency band: 585.94, SINR: 105.23
# frequency band: 593.75, SINR: 111.58
# frequency band: 601.56, SINR: 106.95
# frequency band: 609.38, SINR: 101.59
# frequency band: 617.19, SINR: 98.19
# frequency band: 625.00, SINR: 95.81
# frequency band: 632.81, SINR: 94.03
# frequency band: 640.62, SINR: 92.65
# frequency band: 648.44, SINR: 91.58
# frequency band: 656.25, SINR: 90.74
# frequency band: 664.06, SINR: 90.10
# frequency band: 671.88, SINR: 89.63
# frequency band: 679.69, SINR: 89.33
# frequency band: 687.50, SINR: 89.17
# frequency band: 695.31, SINR: 89.15
# frequency band: 703.12, SINR: 89.27
# frequency band: 710.94, SINR: 89.52
# frequency band: 718.75, SINR: 89.92
# frequency band: 726.56, SINR: 90.47
# frequency band: 734.38, SINR: 91.17
# frequency band: 742.19, SINR: 92.06
# frequency band: 750.00, SINR: 93.15
# frequency band: 757.81, SINR: 94.49
# frequency band: 765.62, SINR: 96.14
# frequency band: 773.44, SINR: 98.24
# frequency band: 781.25, SINR: 100.98
# frequency band: 789.06, SINR: 104.68
# frequency band: 796.88, SINR: 109.06
# frequency band: 804.69, SINR: 108.62
# frequency band: 812.50, SINR: 104.50
# frequency band: 820.31, SINR: 101.31
# frequency band: 828.12, SINR: 99.04
# frequency band: 835.94, SINR: 97.38
# frequency band: 843.75, SINR: 96.14
# frequency band: 851.56, SINR: 95.23
# frequency band: 859.38, SINR: 94.57
# frequency band: 867.19, SINR: 94.14
# frequency band: 875.00, SINR: 93.90
# frequency band: 882.81, SINR: 93.85
# frequency band: 890.62, SINR: 93.98
# frequency band: 898.44, SINR: 94.28
# frequency band: 906.25, SINR: 94.76
# frequency band: 914.06, SINR: 95.44
# frequency band: 921.88, SINR: 96.32
# frequency band: 929.69, SINR: 97.41
# frequency band: 937.50, SINR: 98.72
# frequency band: 945.31, SINR: 100.22
# frequency band: 953.12, SINR: 101.74
# frequency band: 960.94, SINR: 102.90
# frequency band: 968.75, SINR: 103.14
# frequency band: 976.56, SINR: 102.40
# frequency band: 984.38, SINR: 101.21
# frequency band: 992.19, SINR: 100.01
# frequency band: 1000.00, SINR: 99.04
# frequency band: 1007.81, SINR: 98.34
# frequency band: 1015.62, SINR: 97.95
# frequency band: 1023.44, SINR: 97.90
# frequency band: 1031.25, SINR: 98.20
# frequency band: 1039.06, SINR: 98.95
# frequency band: 1046.88, SINR: 100.22
# frequency band: 1054.69, SINR: 102.18
# frequency band: 1062.50, SINR: 104.58
# frequency band: 1070.31, SINR: 105.05
# frequency band: 1078.12, SINR: 101.76
# frequency band: 1085.94, SINR: 97.94
# frequency band: 1093.75, SINR: 94.74
# frequency band: 1101.56, SINR: 92.08
# frequency band: 1109.38, SINR: 89.82
# frequency band: 1117.19, SINR: 87.85
# frequency band: 1125.00, SINR: 86.10
# frequency band: 1132.81, SINR: 84.50
# frequency band: 1140.62, SINR: 83.03
# frequency band: 1148.44, SINR: 81.67
# frequency band: 1156.25, SINR: 80.39
# frequency band: 1164.06, SINR: 79.18
# frequency band: 1171.88, SINR: 78.05
# frequency band: 1179.69, SINR: 77.00
# frequency band: 1187.50, SINR: 76.03
# frequency band: 1195.31, SINR: 75.16
# frequency band: 1203.12, SINR: 74.40
# frequency band: 1210.94, SINR: 73.79
# frequency band: 1218.75, SINR: 73.32
# frequency band: 1226.56, SINR: 73.04
# frequency band: 1234.38, SINR: 72.94
# frequency band: 1242.19, SINR: 73.04
# frequency band: 1250.00, SINR: 73.33
# frequency band: 1257.81, SINR: 73.80
# frequency band: 1265.62, SINR: 74.43
# frequency band: 1273.44, SINR: 75.20
# frequency band: 1281.25, SINR: 76.10
# frequency band: 1289.06, SINR: 77.11
# frequency band: 1296.88, SINR: 78.20
# frequency band: 1304.69, SINR: 79.39
# frequency band: 1312.50, SINR: 80.66
# frequency band: 1320.31, SINR: 82.03
# frequency band: 1328.12, SINR: 83.52
# frequency band: 1335.94, SINR: 85.15
# frequency band: 1343.75, SINR: 86.97
# frequency band: 1351.56, SINR: 89.07
# frequency band: 1359.38, SINR: 91.56
# frequency band: 1367.19, SINR: 94.72
# frequency band: 1375.00, SINR: 99.10
# frequency band: 1382.81, SINR: 106.17
# frequency band: 1390.62, SINR: 108.60
# frequency band: 1398.44, SINR: 101.68
# frequency band: 1406.25, SINR: 97.85
# frequency band: 1414.06, SINR: 95.50
# frequency band: 1421.88, SINR: 93.94
# frequency band: 1429.69, SINR: 92.90
# frequency band: 1437.50, SINR: 92.24
# frequency band: 1445.31, SINR: 91.88
# frequency band: 1453.12, SINR: 91.77
# frequency band: 1460.94, SINR: 91.89
# frequency band: 1468.75, SINR: 92.22
# frequency band: 1476.56, SINR: 92.76
# frequency band: 1484.38, SINR: 93.50
# frequency band: 1492.19, SINR: 94.44
# frequency band: 1500.00, SINR: 95.54
# frequency band: 1507.81, SINR: 96.75
# frequency band: 1515.62, SINR: 97.88
# frequency band: 1523.44, SINR: 98.61
# frequency band: 1531.25, SINR: 98.61
# frequency band: 1539.06, SINR: 97.90
# frequency band: 1546.88, SINR: 96.78
# frequency band: 1554.69, SINR: 95.59
# frequency band: 1562.50, SINR: 94.50
# frequency band: 1570.31, SINR: 93.56
# frequency band: 1578.12, SINR: 92.80
# frequency band: 1585.94, SINR: 92.21
# frequency band: 1593.75, SINR: 91.80
# frequency band: 1601.56, SINR: 91.56
# frequency band: 1609.38, SINR: 91.49
# frequency band: 1617.19, SINR: 91.60
# frequency band: 1625.00, SINR: 91.89
# frequency band: 1632.81, SINR: 92.37
# frequency band: 1640.62, SINR: 93.09
# frequency band: 1648.44, SINR: 94.06
# frequency band: 1656.25, SINR: 95.38
# frequency band: 1664.06, SINR: 97.17
# frequency band: 1671.88, SINR: 99.69
# frequency band: 1679.69, SINR: 103.60
# frequency band: 1687.50, SINR: 111.55
# frequency band: 1695.31, SINR: 116.32
# frequency band: 1703.12, SINR: 104.80
# frequency band: 1710.94, SINR: 99.96
# frequency band: 1718.75, SINR: 96.87
# frequency band: 1726.56, SINR: 94.62
# frequency band: 1734.38, SINR: 92.89
# frequency band: 1742.19, SINR: 91.50
# frequency band: 1750.00, SINR: 90.39
# frequency band: 1757.81, SINR: 89.48
# frequency band: 1765.62, SINR: 88.75
# frequency band: 1773.44, SINR: 88.18
# frequency band: 1781.25, SINR: 87.75
# frequency band: 1789.06, SINR: 87.46
# frequency band: 1796.88, SINR: 87.28
# frequency band: 1804.69, SINR: 87.22
# frequency band: 1812.50, SINR: 87.26
# frequency band: 1820.31, SINR: 87.40
# frequency band: 1828.12, SINR: 87.63
# frequency band: 1835.94, SINR: 87.93
# frequency band: 1843.75, SINR: 88.28
# frequency band: 1851.56, SINR: 88.65
# frequency band: 1859.38, SINR: 89.01
# frequency band: 1867.19, SINR: 89.32
# frequency band: 1875.00, SINR: 89.53
# frequency band: 1882.81, SINR: 89.60
# frequency band: 1890.62, SINR: 89.52
# frequency band: 1898.44, SINR: 89.29
# frequency band: 1906.25, SINR: 88.93
# frequency band: 1914.06, SINR: 88.49
# frequency band: 1921.88, SINR: 87.99
# frequency band: 1929.69, SINR: 87.49
# frequency band: 1937.50, SINR: 86.99
# frequency band: 1945.31, SINR: 86.52
# frequency band: 1953.12, SINR: 86.10
# frequency band: 1960.94, SINR: 85.71
# frequency band: 1968.75, SINR: 85.38
# frequency band: 1976.56, SINR: 85.09
# frequency band: 1984.38, SINR: 84.84
# frequency band: 1992.19, SINR: 84.63
# frequency band: 2000.00, SINR: 84.45
# frequency band: 2007.81, SINR: 84.29
# frequency band: 2015.62, SINR: 84.14
# frequency band: 2023.44, SINR: 84.00
# frequency band: 2031.25, SINR: 83.85
# frequency band: 2039.06, SINR: 83.69
# frequency band: 2046.88, SINR: 83.51
# frequency band: 2054.69, SINR: 83.30
# frequency band: 2062.50, SINR: 83.06
# frequency band: 2070.31, SINR: 82.78
# frequency band: 2078.12, SINR: 82.47
# frequency band: 2085.94, SINR: 82.11
# frequency band: 2093.75, SINR: 81.72
# frequency band: 2101.56, SINR: 81.29
# frequency band: 2109.38, SINR: 80.82
# frequency band: 2117.19, SINR: 80.33
# frequency band: 2125.00, SINR: 79.80
# frequency band: 2132.81, SINR: 79.26
# frequency band: 2140.62, SINR: 78.69
# frequency band: 2148.44, SINR: 78.11
# frequency band: 2156.25, SINR: 77.52
# frequency band: 2164.06, SINR: 76.93
# frequency band: 2171.88, SINR: 76.34
# frequency band: 2179.69, SINR: 75.76
# frequency band: 2187.50, SINR: 75.21
# frequency band: 2195.31, SINR: 74.69
# frequency band: 2203.12, SINR: 74.22
# frequency band: 2210.94, SINR: 73.82
# frequency band: 2218.75, SINR: 73.49
# frequency band: 2226.56, SINR: 73.27
# frequency band: 2234.38, SINR: 73.16
# frequency band: 2242.19, SINR: 73.18
# frequency band: 2250.00, SINR: 73.34
# frequency band: 2257.81, SINR: 73.63
# frequency band: 2265.62, SINR: 74.07
# frequency band: 2273.44, SINR: 74.64
# frequency band: 2281.25, SINR: 75.34
# frequency band: 2289.06, SINR: 76.15
# frequency band: 2296.88, SINR: 77.08
# frequency band: 2304.69, SINR: 78.12
# frequency band: 2312.50, SINR: 79.26
# frequency band: 2320.31, SINR: 80.51
# frequency band: 2328.12, SINR: 81.90
# frequency band: 2335.94, SINR: 83.45
# frequency band: 2343.75, SINR: 85.22
# frequency band: 2351.56, SINR: 87.29
# frequency band: 2359.38, SINR: 89.78
# frequency band: 2367.19, SINR: 92.71
# frequency band: 2375.00, SINR: 95.23
# frequency band: 2382.81, SINR: 94.52
# frequency band: 2390.62, SINR: 91.42
# frequency band: 2398.44, SINR: 88.34
# frequency band: 2406.25, SINR: 85.73
# frequency band: 2414.06, SINR: 83.47
# frequency band: 2421.88, SINR: 81.47
# frequency band: 2429.69, SINR: 79.63
# frequency band: 2437.50, SINR: 77.92
# frequency band: 2445.31, SINR: 76.30
# frequency band: 2453.12, SINR: 74.75
# frequency band: 2460.94, SINR: 73.27
# frequency band: 2468.75, SINR: 71.88
# frequency band: 2476.56, SINR: 70.59
# frequency band: 2484.38, SINR: 69.45
# frequency band: 2492.19, SINR: 68.49
# frequency band: 2500.00, SINR: 67.77
# frequency band: 2507.81, SINR: 67.32
# frequency band: 2515.62, SINR: 67.16
# frequency band: 2523.44, SINR: 67.28
# frequency band: 2531.25, SINR: 67.67
# frequency band: 2539.06, SINR: 68.29
# frequency band: 2546.88, SINR: 69.07
# frequency band: 2554.69, SINR: 69.97
# frequency band: 2562.50, SINR: 70.95
# frequency band: 2570.31, SINR: 71.97
# frequency band: 2578.12, SINR: 73.02
# frequency band: 2585.94, SINR: 74.07
# frequency band: 2593.75, SINR: 75.09
# frequency band: 2601.56, SINR: 76.06
# frequency band: 2609.38, SINR: 76.94
# frequency band: 2617.19, SINR: 77.69
# frequency band: 2625.00, SINR: 78.24
# frequency band: 2632.81, SINR: 78.54
# frequency band: 2640.62, SINR: 78.55
# frequency band: 2648.44, SINR: 78.31
# frequency band: 2656.25, SINR: 77.88
# frequency band: 2664.06, SINR: 77.34
# frequency band: 2671.88, SINR: 76.80
# frequency band: 2679.69, SINR: 76.31
# frequency band: 2687.50, SINR: 75.95
# frequency band: 2695.31, SINR: 75.76
# frequency band: 2703.12, SINR: 75.77
# frequency band: 2710.94, SINR: 76.02
# frequency band: 2718.75, SINR: 76.52
# frequency band: 2726.56, SINR: 77.29
# frequency band: 2734.38, SINR: 78.39
# frequency band: 2742.19, SINR: 79.85
# frequency band: 2750.00, SINR: 81.79
# frequency band: 2757.81, SINR: 84.43
# frequency band: 2765.62, SINR: 88.28
# frequency band: 2773.44, SINR: 94.52
# frequency band: 2781.25, SINR: 96.90
# frequency band: 2789.06, SINR: 90.10
# frequency band: 2796.88, SINR: 85.93
# frequency band: 2804.69, SINR: 83.22
# frequency band: 2812.50, SINR: 81.32
# frequency band: 2820.31, SINR: 79.94
# frequency band: 2828.12, SINR: 78.95
# frequency band: 2835.94, SINR: 78.27
# frequency band: 2843.75, SINR: 77.85
# frequency band: 2851.56, SINR: 77.67
# frequency band: 2859.38, SINR: 77.69
# frequency band: 2867.19, SINR: 77.89
# frequency band: 2875.00, SINR: 78.27
# frequency band: 2882.81, SINR: 78.79
# frequency band: 2890.62, SINR: 79.43
# frequency band: 2898.44, SINR: 80.19
# frequency band: 2906.25, SINR: 81.02
# frequency band: 2914.06, SINR: 81.92
# frequency band: 2921.88, SINR: 82.86
# frequency band: 2929.69, SINR: 83.78
# frequency band: 2937.50, SINR: 84.67
# frequency band: 2945.31, SINR: 85.46
# frequency band: 2953.12, SINR: 86.13
# frequency band: 2960.94, SINR: 86.64
# frequency band: 2968.75, SINR: 86.99
# frequency band: 2976.56, SINR: 87.22
# frequency band: 2984.38, SINR: 87.37
# frequency band: 2992.19, SINR: 87.49
# frequency band: 3000.00, SINR: 87.61
# frequency band: 3007.81, SINR: 87.79
# frequency band: 3015.62, SINR: 88.03
# frequency band: 3023.44, SINR: 88.36
# frequency band: 3031.25, SINR: 88.80
# frequency band: 3039.06, SINR: 89.36
# frequency band: 3046.88, SINR: 90.04
# frequency band: 3054.69, SINR: 90.87
# frequency band: 3062.50, SINR: 91.84
# frequency band: 3070.31, SINR: 92.97
# frequency band: 3078.12, SINR: 94.26
# frequency band: 3085.94, SINR: 95.67
# frequency band: 3093.75, SINR: 97.09
# frequency band: 3101.56, SINR: 98.27
# frequency band: 3109.38, SINR: 98.85
# frequency band: 3117.19, SINR: 98.63
# frequency band: 3125.00, SINR: 97.81
# frequency band: 3132.81, SINR: 96.75
# frequency band: 3140.62, SINR: 95.71
# frequency band: 3148.44, SINR: 94.79
# frequency band: 3156.25, SINR: 94.04
# frequency band: 3164.06, SINR: 93.44
# frequency band: 3171.88, SINR: 93.01
# frequency band: 3179.69, SINR: 92.72
# frequency band: 3187.50, SINR: 92.58
# frequency band: 3195.31, SINR: 92.57
# frequency band: 3203.12, SINR: 92.69
# frequency band: 3210.94, SINR: 92.93
# frequency band: 3218.75, SINR: 93.29
# frequency band: 3226.56, SINR: 93.77
# frequency band: 3234.38, SINR: 94.35
# frequency band: 3242.19, SINR: 95.02
# frequency band: 3250.00, SINR: 95.76
# frequency band: 3257.81, SINR: 96.53
# frequency band: 3265.62, SINR: 97.25
# frequency band: 3273.44, SINR: 97.85
# frequency band: 3281.25, SINR: 98.24
# frequency band: 3289.06, SINR: 98.36
# frequency band: 3296.88, SINR: 98.24
# frequency band: 3304.69, SINR: 97.94
# frequency band: 3312.50, SINR: 97.57
# frequency band: 3320.31, SINR: 97.20
# frequency band: 3328.12, SINR: 96.89
# frequency band: 3335.94, SINR: 96.67
# frequency band: 3343.75, SINR: 96.58
# frequency band: 3351.56, SINR: 96.62
# frequency band: 3359.38, SINR: 96.79
# frequency band: 3367.19, SINR: 97.11
# frequency band: 3375.00, SINR: 97.56
# frequency band: 3382.81, SINR: 98.11
# frequency band: 3390.62, SINR: 98.74
# frequency band: 3398.44, SINR: 99.34
# frequency band: 3406.25, SINR: 99.77
# frequency band: 3414.06, SINR: 99.88
# frequency band: 3421.88, SINR: 99.59
# frequency band: 3429.69, SINR: 98.94
# frequency band: 3437.50, SINR: 98.09
# frequency band: 3445.31, SINR: 97.18
# frequency band: 3453.12, SINR: 96.33
# frequency band: 3460.94, SINR: 95.59
# frequency band: 3468.75, SINR: 94.99
# frequency band: 3476.56, SINR: 94.55
# frequency band: 3484.38, SINR: 94.29
# frequency band: 3492.19, SINR: 94.22
# frequency band: 3500.00, SINR: 94.34
# frequency band: 3507.81, SINR: 94.68
# frequency band: 3515.62, SINR: 95.25
# frequency band: 3523.44, SINR: 96.05
# frequency band: 3531.25, SINR: 97.02
# frequency band: 3539.06, SINR: 97.96
# frequency band: 3546.88, SINR: 98.37
# frequency band: 3554.69, SINR: 97.66
# frequency band: 3562.50, SINR: 95.95
# frequency band: 3570.31, SINR: 93.84
# frequency band: 3578.12, SINR: 91.73
# frequency band: 3585.94, SINR: 89.78
# frequency band: 3593.75, SINR: 87.98
# frequency band: 3601.56, SINR: 86.34
# frequency band: 3609.38, SINR: 84.82
# frequency band: 3617.19, SINR: 83.41
# frequency band: 3625.00, SINR: 82.08
# frequency band: 3632.81, SINR: 80.82
# frequency band: 3640.62, SINR: 79.62
# frequency band: 3648.44, SINR: 78.48
# frequency band: 3656.25, SINR: 77.40
# frequency band: 3664.06, SINR: 76.39
# frequency band: 3671.88, SINR: 75.46
# frequency band: 3679.69, SINR: 74.62
# frequency band: 3687.50, SINR: 73.90
# frequency band: 3695.31, SINR: 73.32
# frequency band: 3703.12, SINR: 72.89
# frequency band: 3710.94, SINR: 72.65
# frequency band: 3718.75, SINR: 72.59
# frequency band: 3726.56, SINR: 72.74
# frequency band: 3734.38, SINR: 73.07
# frequency band: 3742.19, SINR: 73.59
# frequency band: 3750.00, SINR: 74.26
# frequency band: 3757.81, SINR: 75.06
# frequency band: 3765.62, SINR: 75.98
# frequency band: 3773.44, SINR: 77.00
# frequency band: 3781.25, SINR: 78.11
# frequency band: 3789.06, SINR: 79.31
# frequency band: 3796.88, SINR: 80.59
# frequency band: 3804.69, SINR: 81.97
# frequency band: 3812.50, SINR: 83.47
# frequency band: 3820.31, SINR: 85.13
# frequency band: 3828.12, SINR: 87.01
# frequency band: 3835.94, SINR: 89.21
# frequency band: 3843.75, SINR: 91.91
# frequency band: 3851.56, SINR: 95.48
# frequency band: 3859.38, SINR: 100.67
# frequency band: 3867.19, SINR: 106.00
# frequency band: 3875.00, SINR: 101.07
# frequency band: 3882.81, SINR: 96.50
# frequency band: 3890.62, SINR: 93.56
# frequency band: 3898.44, SINR: 91.50
# frequency band: 3906.25, SINR: 89.99
# frequency band: 3914.06, SINR: 88.86
# frequency band: 3921.88, SINR: 88.00
# frequency band: 3929.69, SINR: 87.36
# frequency band: 3937.50, SINR: 86.90
# frequency band: 3945.31, SINR: 86.59
# frequency band: 3953.12, SINR: 86.41
# frequency band: 3960.94, SINR: 86.33
# frequency band: 3968.75, SINR: 86.34
# frequency band: 3976.56, SINR: 86.40
# frequency band: 3984.38, SINR: 86.49
# frequency band: 3992.19, SINR: 86.60
# frequency band: 4000.00, SINR: 86.70
# average SINR: 88.05

# %% [markdown]
# ### Evaluate performance

# %%
# plot peam pattern
fig, ax = room.plot(freq=[250, 1000, 2000, 4000], img_order=0)

# %%
playsound(out_filepath + '/combined_8000_mic_8.wav')

# %%
playsound(out_filepath + '/isolated_src1.wav')

# %%
playsound(out_filepath + '/isolated_src2.wav')

# %%
playsound(out_filepath + '/isolated_src3.wav')
